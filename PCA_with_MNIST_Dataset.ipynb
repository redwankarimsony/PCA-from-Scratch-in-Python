# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

from IPython.display import clear_output

import pandas as pd
import numpy as np
classes = {0:'T-shirt/top',
           1:'Trouser', 
           2: 'Pullover', 
           3: 'Dress', 
           4: 'Coat',
           5: 'Sandal',
           6: 'Shirt',
           7: 'Sneaker',
           8: 'Bag', 
           9: 'Ankle Boot'}

# %%
selected_labels = [0, 1, 5, 8, 9]

data = pd.read_csv('fashion_MNIST/fashion-mnist_train.csv')
data = data.loc[data['label'].isin(selected_labels)].reset_index(drop=True)

labels = data.pop('label')
index = 0
data = data.values
images = np.reshape(data, (-1, 28, 28))

# %%
import matplotlib.pyplot as plt
plt.imshow(images[index].squeeze(), cmap = 'gray')
plt.title(classes[labels[index]])
plt.axis('off')
plt.show()
index += 1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # PCA step by step
# Here is the short summary of the required steps:
# * **Scale the data** — we don’t want some feature to be voted as “more important” due to scale differences. 10m = 10000mm, but the algorithm isn’t aware of meters and millimeters
# * **Calculate covariance matrix** — square matrix giving the covariances between each pair of elements of a random vector
# * **Eigen Decomposition**

# %% [markdown]
# # Scale the Data:
# Standardize features by removing the mean and scaling to unit variance. The standard score of a sample x is calculated as: $$z = \frac{(x - u)}{s}$$
# where $u$ is the mean of the training samples or zero if `with_mean=False`, and $s$ is the standard deviation of the training samples or one if `with_std=False`.

# %%
mean_ = data.mean(axis =0)
std_ = data.std(axis=0)

X_scaled = (data-mean_)/std_

# %% [markdown]
# # Calculate Covariance Matrix:
# Let’s take a step back here and understand the difference between variance and covariance. Variance reports variation of a single random variable — let’s say the weight of a person, and covariance reports how much two random variables vary — like weight and height of a person.
# On the diagonal of the covariance matrix we have variances, and other elements are the covariances.

# %%
print(f'Shape of X_scaled: {X_scaled.shape}')
features = X_scaled.T
print(f'Shape of features: {features.shape}')
cov_matrix = np.cov(features)
print(f'Shape of cov_matrix: {cov_matrix.shape}')
print('\nSneak Peak of the covariance matrix:\n')
cov_matrix[0:5, 0:5]
# Out:
# Shape of X_scaled: (30000, 784)
# Shape of features: (784, 30000)
# Shape of cov_matrix: (784, 784)
#
# Sneak Peak of the covariance matrix:
# array([[1.00003333, 0.10344873, 0.02532451, 0.02635544, 0.0259777 ],
#        [0.10344873, 1.00003333, 0.67948885, 0.16289888, 0.05367159],
#        [0.02532451, 0.67948885, 1.00003333, 0.29368204, 0.0353962 ],
#        [0.02635544, 0.16289888, 0.29368204, 1.00003333, 0.55370309],
#        [0.0259777 , 0.05367159, 0.0353962 , 0.55370309, 1.00003333]])

# %% [markdown]
# As you can see, the diagonal elements are identical, and the matrix is symmetrical. Up next, eigendecomposition.

# %% [markdown]
# # Eigendecomposition
# `Eigendecomposition is a process that decomposes a square matrix into eigenvectors and eigenvalues.` <font color='red'>Eigenvectors are simple unit vectors</font>, and <font color='green'>eigenvalues are coefficients which give the magnitude to the eigenvectors. </font>
#
# We know so far that our `covariance matrix is symmetrical.` As it turns out, `eigenvectors of symmetric matrices are orthogonal.` For PCA this means that we have the first principal component which explains most of the variance. Orthogonal to that is the second principal component, which explains most of the remaining variance. This is repeated for N number of principal components, where N equals to number of original features.
#
# And this turns out to be neat for us — principal components are sorted by percentage of variance explained, as we can decide how many should we keep. For example, if we have 100 features originally, but the first 3 principal components explain 95% of the variance, then it makes sense to keep only these 3 for visualizations and model training.

# %%
eig_values, eig_vectors = np.linalg.eig(cov_matrix)



print(f'First 10 eigenvalues: {eig_values[:10]}')
print(f'\n\nLast 10 eigenvalues: {eig_values[-10:]}')
# Out:
# First 10 eigenvalues: [153.06599858 134.58513832  53.62624634  45.83523074  35.94793614
#   27.1722212   16.16894956  11.26325146   9.89960743   8.76881916]
#
#
# Last 10 eigenvalues: [0.02990182 0.0299665  0.03207515 0.03185936 0.02958344 0.03047201
#  0.03218829 0.02955674 0.03128741 0.03836895]

# %%
plt.figure(figsize=(5,3))
plt.stem(eig_values[:200], use_line_collection = True)
plt.xlabel('Eigen value index')
plt.ylabel('Eigen value')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="698.5714404680293">

# %%
for i in range(200):
    exp_var = np.sum(eig_values[:i+1])*100 / np.sum(eig_values)
    print(f'Eigenvectors upto {i+1} expresses {exp_var} % variance')
# Out:
# Eigenvectors upto 1 expresses 19.52307351819951 % variance
# Eigenvectors upto 2 expresses 36.688973027415834 % variance
# Eigenvectors upto 3 expresses 43.52882746554149 % variance
# Eigenvectors upto 4 expresses 49.374963038968325 % variance
# Eigenvectors upto 5 expresses 53.96000613539753 % variance
# Eigenvectors upto 6 expresses 57.42573514793005 % variance
# Eigenvectors upto 7 expresses 59.48803241770388 % variance
# Eigenvectors upto 8 expresses 60.924623746428274 % variance
# Eigenvectors upto 9 expresses 62.18728668600381 % variance
# Eigenvectors upto 10 expresses 63.305721235345786 % variance
# Eigenvectors upto 11 expresses 64.34015921745096 % variance
# Eigenvectors upto 12 expresses 65.30345377006293 % variance
# Eigenvectors upto 13 expresses 66.22157672421163 % variance
# Eigenvectors upto 14 expresses 66.99535115019914 % variance
# Eigenvectors upto 15 expresses 67.7405661325227 % variance
# Eigenvectors upto 16 expresses 68.43816735826334 % variance
# Eigenvectors upto 17 expresses 69.0614481592864 % variance
# Eigenvectors upto 18 expresses 69.65721522913012 % variance
# Eigenvectors upto 19 expresses 70.2326337831485 % variance
# Eigenvectors upto 20 expresses 70.77409539692968 % variance
# Eigenvectors upto 21 expresses 71.28998391299852 % variance
# Eigenvectors upto 22 expresses 71.7786736024929 % variance
# Eigenvectors upto 23 expresses 72.25301371878176 % variance
# Eigenvectors upto 24 expresses 72.70715322014469 % variance
# Eigenvectors upto 25 expresses 73.1504989343933 % variance
# Eigenvectors upto 26 expresses 73.579263460662 % variance
# Eigenvectors upto 27 expresses 73.99083874980501 % variance
# Eigenvectors upto 28 expresses 74.36499478480827 % variance
# Eigenvectors upto 29 expresses 74.73228664199708 % variance
# Eigenvectors upto 30 expresses 75.09208305657283 % variance
# Eigenvectors upto 31 expresses 75.43579532969464 % variance
# Eigenvectors upto 32 expresses 75.76003634117211 % variance
# Eigenvectors upto 33 expresses 76.07692505971893 % variance
# Eigenvectors upto 34 expresses 76.3901000819041 % variance
# Eigenvectors upto 35 expresses 76.6995178596562 % variance
# Eigenvectors upto 36 expresses 76.99973490374106 % variance
# Eigenvectors upto 37 expresses 77.29743741102457 % variance
# Eigenvectors upto 38 expresses 77.57746353284107 % variance
# Eigenvectors upto 39 expresses 77.85557690851203 % variance
# Eigenvectors upto 40 expresses 78.1184715157781 % variance
# Eigenvectors upto 41 expresses 78.37460096541022 % variance
# Eigenvectors upto 42 expresses 78.62937568007641 % variance
# Eigenvectors upto 43 expresses 78.87777483330171 % variance
# Eigenvectors upto 44 expresses 79.11572208615503 % variance
# Eigenvectors upto 45 expresses 79.34999900941528 % variance
# Eigenvectors upto 46 expresses 79.57892203584002 % variance
# Eigenvectors upto 47 expresses 79.80519748448566 % variance
# Eigenvectors upto 48 expresses 80.02688232660728 % variance
# Eigenvectors upto 49 expresses 80.24170591534306 % variance
# Eigenvectors upto 50 expresses 80.45463843255443 % variance
# Eigenvectors upto 51 expresses 80.66108561111126 % variance
# Eigenvectors upto 52 expresses 80.86249284501672 % variance
# Eigenvectors upto 53 expresses 81.06125443584011 % variance
# Eigenvectors upto 54 expresses 81.2515651040952 % variance
# Eigenvectors upto 55 expresses 81.43949969033733 % variance
# Eigenvectors upto 56 expresses 81.62303601884608 % variance
# Eigenvectors upto 57 expresses 81.8034662726157 % variance
# Eigenvectors upto 58 expresses 81.98259551293376 % variance
# Eigenvectors upto 59 expresses 82.15807146471792 % variance
# Eigenvectors upto 60 expresses 82.3297085643332 % variance
# Eigenvectors upto 61 expresses 82.49512738608585 % variance
# Eigenvectors upto 62 expresses 82.65898721427412 % variance
# Eigenvectors upto 63 expresses 82.81889049024566 % variance
# Eigenvectors upto 64 expresses 82.98033615482284 % variance
# Eigenvectors upto 65 expresses 83.13693566676622 % variance
# Eigenvectors upto 66 expresses 83.29189512616546 % variance
# Eigenvectors upto 67 expresses 83.44392797509394 % variance
# Eigenvectors upto 68 expresses 83.59467704525079 % variance
# Eigenvectors upto 69 expresses 83.7418503728136 % variance
# Eigenvectors upto 70 expresses 83.88871842769693 % variance
# Eigenvectors upto 71 expresses 84.03185385046423 % variance
# Eigenvectors upto 72 expresses 84.17265034243758 % variance
# Eigenvectors upto 73 expresses 84.31171401339918 % variance
# Eigenvectors upto 74 expresses 84.44748817536443 % variance
# Eigenvectors upto 75 expresses 84.58199195122027 % variance
# Eigenvectors upto 76 expresses 84.71630025803307 % variance
# Eigenvectors upto 77 expresses 84.84685575346772 % variance
# Eigenvectors upto 78 expresses 84.97628021705385 % variance
# Eigenvectors upto 79 expresses 85.1046106955414 % variance
# Eigenvectors upto 80 expresses 85.23038207999024 % variance
# Eigenvectors upto 81 expresses 85.35423941474224 % variance
# Eigenvectors upto 82 expresses 85.47734596146172 % variance
# Eigenvectors upto 83 expresses 85.597867694012 % variance
# Eigenvectors upto 84 expresses 85.7176126734849 % variance
# Eigenvectors upto 85 expresses 85.83427598795198 % variance
# Eigenvectors upto 86 expresses 85.94667144011598 % variance
# Eigenvectors upto 87 expresses 86.05804729067123 % variance
# Eigenvectors upto 88 expresses 86.16806024394397 % variance
# Eigenvectors upto 89 expresses 86.27677116763566 % variance
# Eigenvectors upto 90 expresses 86.38486080653021 % variance
# Eigenvectors upto 91 expresses 86.4911516692365 % variance
# Eigenvectors upto 92 expresses 86.59561189419864 % variance
# Eigenvectors upto 93 expresses 86.69849364741239 % variance
# Eigenvectors upto 94 expresses 86.80027090816803 % variance
# Eigenvectors upto 95 expresses 86.90161296985822 % variance
# Eigenvectors upto 96 expresses 87.00113630636672 % variance
# Eigenvectors upto 97 expresses 87.09951895063665 % variance
# Eigenvectors upto 98 expresses 87.19660211966993 % variance
# Eigenvectors upto 99 expresses 87.29277359021044 % variance
# Eigenvectors upto 100 expresses 87.38881789642267 % variance
# Eigenvectors upto 101 expresses 87.48236516319254 % variance
# Eigenvectors upto 102 expresses 87.5753302055165 % variance
# Eigenvectors upto 103 expresses 87.66759757589003 % variance
# Eigenvectors upto 104 expresses 87.7576680315948 % variance
# Eigenvectors upto 105 expresses 87.84708182521852 % variance
# Eigenvectors upto 106 expresses 87.93534162703313 % variance
# Eigenvectors upto 107 expresses 88.0228241288049 % variance
# Eigenvectors upto 108 expresses 88.10922369152387 % variance
# Eigenvectors upto 109 expresses 88.19461142518112 % variance
# Eigenvectors upto 110 expresses 88.27926424865 % variance
# Eigenvectors upto 111 expresses 88.36321903538744 % variance
# Eigenvectors upto 112 expresses 88.44293046908514 % variance
# Eigenvectors upto 113 expresses 88.5234573133945 % variance
# Eigenvectors upto 114 expresses 88.60511749059563 % variance
# Eigenvectors upto 115 expresses 88.68823622657737 % variance
# Eigenvectors upto 116 expresses 88.77094119102681 % variance
# Eigenvectors upto 117 expresses 88.84876593579176 % variance
# Eigenvectors upto 118 expresses 88.92532319841632 % variance
# Eigenvectors upto 119 expresses 89.00149325593576 % variance
# Eigenvectors upto 120 expresses 89.07600350317712 % variance
# Eigenvectors upto 121 expresses 89.15019232784977 % variance
# Eigenvectors upto 122 expresses 89.22300947532432 % variance
# Eigenvectors upto 123 expresses 89.29436901348296 % variance
# Eigenvectors upto 124 expresses 89.36543236585456 % variance
# Eigenvectors upto 125 expresses 89.4360670784913 % variance
# Eigenvectors upto 126 expresses 89.50612896512592 % variance
# Eigenvectors upto 127 expresses 89.57571706854156 % variance
# Eigenvectors upto 128 expresses 89.64460990942085 % variance
# Eigenvectors upto 129 expresses 89.71154468191679 % variance
# Eigenvectors upto 130 expresses 89.77942039245 % variance
# Eigenvectors upto 131 expresses 89.84705899762471 % variance
# Eigenvectors upto 132 expresses 89.91311796861778 % variance
# Eigenvectors upto 133 expresses 89.97960533928817 % variance
# Eigenvectors upto 134 expresses 90.04536005562713 % variance
# Eigenvectors upto 135 expresses 90.11038226124943 % variance
# Eigenvectors upto 136 expresses 90.17494416119077 % variance
# Eigenvectors upto 137 expresses 90.23875262895227 % variance
# Eigenvectors upto 138 expresses 90.30197028883765 % variance
# Eigenvectors upto 139 expresses 90.3643325831529 % variance
# Eigenvectors upto 140 expresses 90.42517432575785 % variance
# Eigenvectors upto 141 expresses 90.48638023269042 % variance
# Eigenvectors upto 142 expresses 90.54811523499869 % variance
# Eigenvectors upto 143 expresses 90.60812064044953 % variance
# Eigenvectors upto 144 expresses 90.66681476876717 % variance
# Eigenvectors upto 145 expresses 90.72709045820137 % variance
# Eigenvectors upto 146 expresses 90.78419412669153 % variance
# Eigenvectors upto 147 expresses 90.84328490369019 % variance
# Eigenvectors upto 148 expresses 90.90245199738949 % variance
# Eigenvectors upto 149 expresses 90.95987544310047 % variance
# Eigenvectors upto 150 expresses 91.01657450205359 % variance
# Eigenvectors upto 151 expresses 91.0721155115703 % variance
# Eigenvectors upto 152 expresses 91.12819077894744 % variance
# Eigenvectors upto 153 expresses 91.18385287310814 % variance
# Eigenvectors upto 154 expresses 91.23897361954053 % variance
# Eigenvectors upto 155 expresses 91.29344756876225 % variance
# Eigenvectors upto 156 expresses 91.3475517593638 % variance
# Eigenvectors upto 157 expresses 91.4012112193942 % variance
# Eigenvectors upto 158 expresses 91.45426306300875 % variance
# Eigenvectors upto 159 expresses 91.50670923095085 % variance
# Eigenvectors upto 160 expresses 91.55859360579743 % variance
# Eigenvectors upto 161 expresses 91.61016101616129 % variance
# Eigenvectors upto 162 expresses 91.66088512142169 % variance
# Eigenvectors upto 163 expresses 91.71117756770843 % variance
# Eigenvectors upto 164 expresses 91.76120618222137 % variance
# Eigenvectors upto 165 expresses 91.8110370319363 % variance
# Eigenvectors upto 166 expresses 91.86034558114102 % variance
# Eigenvectors upto 167 expresses 91.90927071424558 % variance
# Eigenvectors upto 168 expresses 91.95793128301715 % variance
# Eigenvectors upto 169 expresses 92.00612988140728 % variance
# Eigenvectors upto 170 expresses 92.05402852364746 % variance
# Eigenvectors upto 171 expresses 92.10178839213448 % variance
# Eigenvectors upto 172 expresses 92.1490948473306 % variance
# Eigenvectors upto 173 expresses 92.19621186223424 % variance
# Eigenvectors upto 174 expresses 92.24300773302602 % variance
# Eigenvectors upto 175 expresses 92.289412262129 % variance
# Eigenvectors upto 176 expresses 92.33559587383428 % variance
# Eigenvectors upto 177 expresses 92.38141930664119 % variance
# Eigenvectors upto 178 expresses 92.42650775787637 % variance
# Eigenvectors upto 179 expresses 92.4717191049346 % variance
# Eigenvectors upto 180 expresses 92.51641709989424 % variance
# Eigenvectors upto 181 expresses 92.56078620151348 % variance
# Eigenvectors upto 182 expresses 92.60462502416291 % variance
# Eigenvectors upto 183 expresses 92.64769112002959 % variance
# Eigenvectors upto 184 expresses 92.69128418105628 % variance
# Eigenvectors upto 185 expresses 92.73380308892406 % variance
# Eigenvectors upto 186 expresses 92.77591722057856 % variance
# Eigenvectors upto 187 expresses 92.81790880206297 % variance
# Eigenvectors upto 188 expresses 92.85960430842415 % variance
# Eigenvectors upto 189 expresses 92.90093950818095 % variance
# Eigenvectors upto 190 expresses 92.94211943770702 % variance
# Eigenvectors upto 191 expresses 92.9830927853596 % variance
# Eigenvectors upto 192 expresses 93.02368940424195 % variance
# Eigenvectors upto 193 expresses 93.06387924339074 % variance
# Eigenvectors upto 194 expresses 93.10372885357258 % variance
# Eigenvectors upto 195 expresses 93.14317082722656 % variance
# Eigenvectors upto 196 expresses 93.18285506644709 % variance
# Eigenvectors upto 197 expresses 93.2218691094435 % variance
# Eigenvectors upto 198 expresses 93.26078276733305 % variance
# Eigenvectors upto 199 expresses 93.2994206594282 % variance
# Eigenvectors upto 200 expresses 93.33800668132712 % variance

# %% [markdown]
# # Visualizations
# ## Eigenvector Visualization

# %%
X_scaled[0].reshape((-1, 784)).shape
# Out:
# (1, 784)

# %%
eig_vectors[:, 0].reshape((784, -1)).shape
# Out:
# (784, 1)

# %%
result = np.dot(X_scaled.reshape((-1, 784)), eig_vectors[:,:50].reshape((784, -1)))
result.shape
# Out:
# (30000, 50)

# %%
projected_1 = X_scaled.dot(eig_vectors.T[0])
projected_2 = X_scaled.dot(eig_vectors.T[1])
res2d = pd.DataFrame(projected_1, columns=['PC1'])
res2d['PC2'] = projected_2
res2d['Y'] = labels
res2d.head()
# Out:
#          PC1        PC2  Y
# 0 -13.846035  -3.141500  9
# 1  13.780054   8.119654  0
# 2  -4.080987 -20.163169  5
# 3   4.344533   0.808241  8
# 4  21.412902  19.844596  0

# %% [markdown]
# ## 2D Visualization

# %%
plt.figure(figsize=(6,4))
for label in selected_labels:
    label_name = classes[label]
    coords = res2d[res2d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    plt.scatter(x, y, label=label_name)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.2857278974691">

# %% [markdown]
# ## 3D Visualization

# %%
projected_1 = X_scaled.dot(eig_vectors.T[0])
projected_2 = X_scaled.dot(eig_vectors.T[1])
projected_3 = X_scaled.dot(eig_vectors.T[2])
res3d = pd.DataFrame(projected_1, columns=['PC1'])
res3d['PC2'] = projected_2
res3d['PC3'] = projected_3
res3d['Y'] = labels
res3d = res3d.head(500)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')

for label in selected_labels:
    label_name = classes[label]
    coords = res3d[res3d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    z = coords['PC3'].values
    ax.scatter3D(x, y, z, label=label_name)
    
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="560">

# %% [markdown]
# # Reconstruction from Principal Component
# ## Reduction/Compression Phase:

# %%
reduced_eigen_space = eig_vectors[:, :350]

# %%
print(f'Shape of X_scaled: {X_scaled.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
X_compressed = np.dot(X_scaled, reduced_eigen_space)
print(f'Shape of X_compressed: {X_compressed.shape}')
# Out:
# Shape of X_scaled: (30000, 784)
# Shape of reduced_eigen_space: (784, 350)
# Shape of X_compressed: (30000, 350)

# %%
print(f'Shape of X_compressed: {X_compressed.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
X_reconstructed = np.dot(X_compressed,reduced_eigen_space.T)
print(f'Shape of X_reconstructed: {X_reconstructed.shape}')
# Out:
# Shape of X_compressed: (30000, 350)
# Shape of reduced_eigen_space: (784, 350)
# Shape of X_reconstructed: (30000, 784)

# %%
data_reconstructed = (X_reconstructed * std_ ) + mean_
reconstructed_images = np.reshape(data_reconstructed, (-1, 28, 28))

# %%
rec_index = 0

# %%
f = plt.figure()
ax1 = f.add_subplot(1,2,1)
plt.imshow(images[rec_index].squeeze(), cmap = 'gray')
ax1.axis(False)
ax2 = f.add_subplot(1,2,2)
ax2.axis(False)
plt.imshow(reconstructed_images[rec_index].squeeze(), cmap = 'gray')
ax1.title.set_text('Original')
ax2.title.set_text('Reconstructed after Compression')
plt.show(block=True)
rec_index +=1
# Out:
# <img src="data:image/png;base64,..." width="895.0000152417595">
